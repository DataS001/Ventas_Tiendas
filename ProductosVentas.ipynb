# %% [markdown]
# # Productos más y menos vendidos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# # Tienda 1

# %%
def top_bottom_selling_products(df, n=5):
    """Identifica los n productos más y menos vendidos por cantidad."""
    product_counts = df['Producto'].value_counts()
    if n > 0:
        return product_counts.nlargest(n)
    elif n < 0:
        return product_counts.nsmallest(abs(n))
    else:
        return pd.Series()  # Devuelve una Serie vacía si n es 0

top_productos_tienda1 = top_bottom_selling_products(tienda)
bottom_productos_tienda1 = top_bottom_selling_products(tienda, n=-5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 11
#       8     else:
#       9         return pd.Series()  # Devuelve una Serie vacía si n es 0
# ---> 11 top_productos_tienda1 = top_bottom_selling_products(tienda)
#      12 bottom_productos_tienda1 = top_bottom_selling_products(tienda, n=-5)
#
# NameError: name 'tienda' is not defined

# %%
def top_bottom_selling_products(df, n=5):
    """Identifica los n productos más y menos vendidos por cantidad."""
    if 'Cantidad' in df.columns:
        product_counts = df.groupby('Producto')['Cantidad'].sum().sort_values(ascending=False)
    else:
        product_counts = df['Producto'].value_counts()
    if n > 0:
        return product_counts.head(n)
    elif n < 0:
        return product_counts.tail(abs(n))
    else:
        return pd.Series()  # Devuelve una Serie vacía si n es 0

# %% [markdown]
# # Tienda 2

# %%
def top_bottom_selling_products(df, n=5):
    """Identifica los n productos más y menos vendidos por cantidad."""
    product_counts = df['Producto'].value_counts()
    if n > 0:
        return product_counts.nlargest(n)
    elif n < 0:
        return product_counts.nsmallest(abs(n))
    else:
        return pd.Series()  # Devuelve una Serie vacía si n es 0

top_productos_tienda2 = top_bottom_selling_products(tienda2)
bottom_productos_tienda2 = top_bottom_selling_products(tienda2, n=-5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       8     else:
#       9         return pd.Series()  # Devuelve una Serie vacía si n es 0
# ---> 11 top_productos_tienda2 = top_bottom_selling_products(tienda2)
#      12 bottom_productos_tienda2 = top_bottom_selling_products(tienda2, n=-5)
#
# NameError: name 'tienda2' is not defined

# %%
def top_bottom_selling_products(df, n=5):
    """Identifica los n productos más y menos vendidos por cantidad."""
    product_counts = df['Producto'].value_counts()
    if n > 0:
        return product_counts.nlargest(n)
    elif n < 0:
        return product_counts.nsmallest(abs(n))
    else:
        return pd.Series()  # Devuelve una Serie vacía si n es 0

top_productos_tienda3 = top_bottom_selling_products(tienda3)
bottom_productos_tienda3 = top_bottom_selling_products(tienda3, n=-5)
print (bottom_productos_tienda3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       8     else:
#       9         return pd.Series()  # Devuelve una Serie vacía si n es 0
# ---> 11 top_productos_tienda3 = top_bottom_selling_products(tienda3)
#      12 bottom_productos_tienda3 = top_bottom_selling_products(tienda3, n=-5)
#      13 print (bottom_productos_tienda3)
#
# NameError: name 'tienda3' is not defined

# %%
def top_bottom_selling_products(df, n=5):
    """Identifica los n productos más y menos vendidos por cantidad."""
    product_counts = df['Producto'].value_counts()
    if n > 0:
        return product_counts.nlargest(n)
    elif n < 0:
        return product_counts.nsmallest(abs(n))
    else:
        return pd.Series()  # Devuelve una Serie vacía si n es 0

top_productos_tienda4 = top_bottom_selling_products(tienda4)
bottom_productos_tienda4 = top_bottom_selling_products(tienda4, n=-5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8     else:
#       9         return pd.Series()  # Devuelve una Serie vacía si n es 0
# ---> 11 top_productos_tienda4 = top_bottom_selling_products(tienda4)
#      12 bottom_productos_tienda4 = top_bottom_selling_products(tienda4, n=-5)
#
# NameError: name 'tienda4' is not defined

# %%
bottom_productos_tienda4 = top_bottom_selling_products(tienda4, n=-5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 bottom_productos_tienda4 = top_bottom_selling_products(tienda4, n=-5)
#
# NameError: name 'top_bottom_selling_products' is not defined

# %%
import pandas as pd

# --- 1. Cargar los datos ---
url_tienda1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url_tienda2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url_tienda3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url_tienda4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1_df = pd.read_csv(url_tienda1)
tienda2_df = pd.read_csv(url_tienda2)
tienda3_df = pd.read_csv(url_tienda3)
tienda4_df = pd.read_csv(url_tienda4)

# --- 2. Función para obtener n productos más y menos vendidos ---
def top_bottom_selling_products(df, n=5):
    """Identifica los n productos más y menos vendidos por cantidad real."""
    if 'Cantidad' in df.columns:
        # Suma la columna 'Cantidad' por producto
        product_counts = df.groupby('Producto')['Cantidad'].sum().sort_values(ascending=False)
    else:
        # Cuenta las filas por producto (si no hay columna 'Cantidad')
        product_counts = df['Producto'].value_counts()
    top_n = product_counts.head(n)
    bottom_n = product_counts.tail(n)
    return top_n, bottom_n

# --- 3. Obtener productos top y bottom por tienda ---
top_tienda1, bottom_tienda1 = top_bottom_selling_products(tienda1_df)
top_tienda2, bottom_tienda2 = top_bottom_selling_products(tienda2_df)
top_tienda3, bottom_tienda3 = top_bottom_selling_products(tienda3_df)
top_tienda4, bottom_tienda4 = top_bottom_selling_products(tienda4_df)

# --- 4. Imprimir resultados ---
def print_top_bottom_products(top_products, bottom_products, store_name):
    """Imprime los productos más y menos vendidos en la consola."""
    print(f"\n=== {store_name} ===")
    if not top_products.empty:
        print("\nProductos MÁS vendidos (Cantidad):")
        print(top_products)
    else:
        print("\nNo hay productos más vendidos.")
    if not bottom_products.empty:
        print("\nProductos MENOS vendidos (Cantidad):")
        print(bottom_products)
    else:
        print("\nNo hay productos menos vendidos.")

print_top_bottom_products(top_tienda1, bottom_tienda1, 'Tienda 1')
print_top_bottom_products(top_tienda2, bottom_tienda2, 'Tienda 2')
print_top_bottom_products(top_tienda3, bottom_tienda3, 'Tienda 3')
print_top_bottom_products(top_tienda4, bottom_tienda4, 'Tienda 4')
