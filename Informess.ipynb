# %% [markdown]
# # 1. INFORME GENERAL

# %% [markdown]
# ![Ingresos Tiendas](ingresos_totales_Tiendas.png)

# %% [markdown]
# La Tabla 1 representa los ingresos totales de las cuatro tiendas, con valores que van desde 0.0 hasta 1,200 millones. En general, la Tienda 1, representada por el color azul, muestra los ingresos más altos. Le sigue la Tienda 2, que ocupa el segundo lugar con una diferencia de 34,536,900 en comparación con la primera tienda. Por su parte, la Tienda 3 presenta una ligera desventaja, registrando poco más de 52 millones de pesos menos que la primera y la segunda tienda. Finalmente, la Tienda 4 reporta los ingresos más bajos.

# %% [markdown]
# Como puedo descargar este informe en pdf o word
# #![Ingresos Tiendas](ingresos_totales_Tiendas.png) #

# %% [markdown]
# ![Ventas de Tienda 1] (Ventas_Tienda 1.png)
